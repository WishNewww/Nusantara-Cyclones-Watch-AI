# %%
# %cd /content/Nusantara-Cyclone-AI
# Out:
# /content/Nusantara-Cyclone-AI

# %%
# !pip install -r requirements.txt

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6Jx65pA3QwLBypnpCtc9rxqOvsqkVJhzVEfFyB5U9R4qQ"
print(os.getenv("GOOGLE_API_KEY"))
# Out:
# AQ.Ab8RN6Jx65pA3QwLBypnpCtc9rxqOvsqkVJhzVEfFyB5U9R4qQ

# %%
# !python build_vector.py
# Out:
# 2026-07-06 06:09:59,119 | INFO     | Loaded 108320 observations across 2 region file(s).
# 2026-07-06 06:10:13,278 | INFO     | Built 2303 cyclone document(s) from 108320 observation(s).
# 2026-07-06 06:10:25,157 | INFO     | TensorFlow version 2.20.0 available.
# 2026-07-06 06:10:25,158 | INFO     | JAX version 0.7.2 available.
# 2026-07-06 06:10:32,944 | INFO     | No device provided, using cpu
# 2026-07-06 06:10:33,105 | INFO     | HTTP Request: GET https://huggingface.co/api/agent-harnesses "HTTP/1.1 200 OK"
# 2026-07-06 06:10:33,167 | INFO     | HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 2026-07-06 06:10:33,168 | WARNING  | Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 45.9 MB/s eta 0:00:00
# ...

# %%
import subprocess

process = subprocess.Popen(
    ["streamlit", "run", "app.py", "--server.port=8501"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE
)

print("Streamlit berjalan di background.")
# Out:
# Streamlit berjalan di background.

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3G49blVP7040FrC9wBJocn95jiZ_6prA7H9PqthHd9qLe4PEE")

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://lubricant-plausibly-contempt.ngrok-free.dev" -> "http://localhost:8501"
